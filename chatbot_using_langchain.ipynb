# %% [markdown]
# **Installing langchain**
#
# ---

# %%
# !pip install -q -U langchain community langchain-groq

# %% [markdown]
# Importing Modlues

# %%
import os
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

# %%
os.environ["GROQ_API_KEY"] = "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"

# %%
llm = ChatGroq(model = "llama-3.1-8b-instant",temperature = 0.9)

# %%
parser = StrOutputParser()

# %%
def chat():
  chat_history = [
      ("system","you are a helpful ai assistant")
  ]
  print("This is a Langchain Chatbot. type 'exit' to Leave.\n")

  while True:
    user_input = input("You : ").strip()

    if user_input.lower()=="exit":
      break

    chat_history.append(("user",user_input))

    prompt = ChatPromptTemplate.from_messages(chat_history)

    chain = prompt | llm | parser

    response = chain.invoke({})

    print(f"Bot: {response}\n")
    chat_history.append(("assistant",response))
    print("-"*50)

# %%
chat()
# Out:
# This is a Langchain Chatbot. type 'exit' to Leave.
#
# You : exit
